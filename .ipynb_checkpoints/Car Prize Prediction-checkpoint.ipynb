# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense 
from tensorflow.keras.optimizers import Adam, SGD

# %% [markdown]
# # Loading Data

# %%
datafile = pd.read_csv('CarPrice_Assignment.csv')

# %%
datafile.head
# Out:
# <bound method NDFrame.head of      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
datafile.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %% [markdown]
# # Checking Missing Values

# %%
missing_values = ["Na", "" , "np.NaN" , None]

# %%
missing = datafile.isin(missing_values)
missing.head()
# Out:
#    car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0   False      False    False     False       False       False    False
# 1   False      False    False     False       False       False    False
# 2   False      False    False     False       False       False    False
# 3   False      False    False     False       False       False    False
# 4   False      False    False     False       False       False    False
#
#    drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0       False           False      False  ...       False       False
# 1       False           False      False  ...       False       False
# 2       False           False      False  ...       False       False
# 3       False           False      False  ...       False       False
# 4       False           False      False  ...       False       False
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
datafile.shape
# Out:
# (205, 26)

# %%
print(datafile.columns)
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %% [markdown]
# # Converting non nomerical data into nomerical data

# %%
datafile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
datafile['fueltype'] = labelencoder.fit_transform(datafile['fueltype'])
datafile['aspiration'] = labelencoder.fit_transform(datafile['aspiration'])
datafile['carbody'] = labelencoder.fit_transform(datafile['carbody'])
datafile['drivewheel'] = labelencoder.fit_transform(datafile['drivewheel'])
datafile['enginelocation'] = labelencoder.fit_transform(datafile['enginelocation'])
datafile['fuelsystem'] = labelencoder.fit_transform(datafile['enginelocation'])

# %%
datafile['doornumber'] = datafile['doornumber'].map({'two':2,'four':4})

# %%
#datafile['doornumber']
datafile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    int32
#  4   aspiration        205 non-null    int32
#  5   doornumber        205 non-null    int64
#  6   carbody           205 non-null    int32
#  7   drivewheel        205 non-null    int32
#  8   enginelocation    205 non-null    int32
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
datafile.head(10)
# Out:
#    car_ID  symboling                   CarName  fueltype  aspiration  \
# 0       1          3        alfa-romero giulia         1           0
# 1       2          3       alfa-romero stelvio         1           0
# 2       3          1  alfa-romero Quadrifoglio         1           0
# 3       4          2               audi 100 ls         1           0
# 4       5          2                audi 100ls         1           0
# 5       6          2                  audi fox         1           0
# 6       7          1                audi 100ls         1           0
# 7       8          1                 audi 5000         1           0
# 8       9          1                 audi 4000         1           1
# 9      10          0       audi 5000s (diesel)         1           1
#
#    doornumber  carbody  drivewheel  enginelocation  wheelbase  ...  \
# 0           2        0           2               0       88.6  ...
# 1           2        0           2               0       88.6  ...
# ...

# %%
datafile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    int32
#  4   aspiration        205 non-null    int32
#  5   doornumber        205 non-null    int64
#  6   carbody           205 non-null    int32
#  7   drivewheel        205 non-null    int32
#  8   enginelocation    205 non-null    int32
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
corrmat = datafile.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(15,15))
g=sns.heatmap(datafile[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# # Selecting Feautures can Affect Price form the Data

# %%
data1 = datafile[['horsepower','boreratio','enginesize','curbweight','carwidth','carlength',
              'wheelbase','drivewheel','price','enginelocation']]

# %%
print(data1.shape)
# Out:
# (205, 10)

# %%
data1.head()
# Out:
#    horsepower  boreratio  enginesize  curbweight  carwidth  carlength  \
# 0         111       3.47         130        2548      64.1      168.8
# 1         111       3.47         130        2548      64.1      168.8
# 2         154       2.68         152        2823      65.5      171.2
# 3         102       3.19         109        2337      66.2      176.6
# 4         115       3.19         136        2824      66.4      176.6
#
#    wheelbase  drivewheel    price  enginelocation
# 0       88.6           2  13495.0               0
# 1       88.6           2  16500.0               0
# 2       94.5           2  16500.0               0
# 3       99.8           1  13950.0               0
# 4       99.4           0  17450.0               0

# %%
data1.shape
# Out:
# (205, 10)

# %%
x = (data1.loc[:, data1.columns != 'price'])
y = (data1.loc[:, data1.columns == 'price'])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)

# %%
x_train.shape
# Out:
# (143, 9)

# %%
x_test.shape
# Out:
# (62, 9)

# %%
model = models.Sequential()
def build_model():
    
    
    model.add(tf.keras.layers.Dense(64, activation='relu'),input_shape =(9,))
    
    model.add(tf.keras.layers.Dense(1,))
   
    return model

# %%
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %%
model.fit(x_train, x_test, epochs=500)

# %%
test_loss, test_acc =  network.evaluate(y_train, y_test)
print('test acc' , test_acc)

# %%
# predicting the test set results
y_pred = model.predict(x_test)

# %%
y_pred[0]
# Out:
# array([1.820e+02, 3.620e+00, 2.090e+02, 3.230e+03, 6.690e+01, 1.890e+02,
#        1.035e+02, 2.000e+00, 0.000e+00])
